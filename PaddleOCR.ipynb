# %% [markdown]
# <a href="https://colab.research.google.com/github/Matteriegray/paddle/blob/main/PaddleOCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import mnist
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import numpy as np
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# !python -m pip install paddlepaddle
# !pip install "paddleocr>=2.0.1"


from paddleocr import PaddleOCR,draw_ocr
import matplotlib.pyplot as plt
import cv2
import os

# %%
ocr_model = PaddleOCR(lang='en')
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100%|██████████| 3910/3910 [00:16<00:00, 242.03it/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to /root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer/en_PP-OCRv4_rec_infer.tar
# 100%|██████████| 10000/10000 [00:18<00:00, 528.54it/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2138/2138 [00:15<00:00, 136.09it/s]
# ...

# %%
img_path = os.path.join('/content','bill.jpg')

img_path
# Out:
# '/content/bill.jpg'

# %%
result = ocr_model.ocr(img_path, cls = True)[0]
result
# Out:
# [2025/04/04 20:30:29] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/04/04 20:30:29] ppocr DEBUG: dt_boxes num : 26, elapsed : 0.19530534744262695
# [2025/04/04 20:30:33] ppocr DEBUG: rec_res num  : 26, elapsed : 3.788083553314209
# [[[[269.0, 72.0], [336.0, 72.0], [336.0, 90.0], [269.0, 90.0]],
#   ('RECEIPT', 0.9952478408813477)],
#  [[[173.0, 115.0], [234.0, 115.0], [234.0, 129.0], [173.0, 129.0]],
#   ('Terminal#1', 0.9924618005752563)],
#  [[[319.0, 117.0], [377.0, 117.0], [377.0, 128.0], [319.0, 128.0]],
#   ('01-02-2018', 0.9920256733894348)],
#  [[[387.0, 117.0], [431.0, 117.0], [431.0, 128.0], [387.0, 128.0]],
#   ('11:32AM', 0.9550370573997498)],
#  [[[171.0, 156.0], [238.0, 156.0], [238.0, 173.0], [171.0, 173.0]],
#   ('1xT-Shirt', 0.9747217893600464)],
#  [[[387.0, 155.0], [433.0, 155.0], [433.0, 173.0], [387.0, 173.0]],
#   ('$25.50', 0.9977073073387146)],
# ...

# %%
for res in result:
  print(res[0])
# Out:
# [[269.0, 72.0], [336.0, 72.0], [336.0, 90.0], [269.0, 90.0]]
# [[173.0, 115.0], [234.0, 115.0], [234.0, 129.0], [173.0, 129.0]]
# [[319.0, 117.0], [377.0, 117.0], [377.0, 128.0], [319.0, 128.0]]
# [[387.0, 117.0], [431.0, 117.0], [431.0, 128.0], [387.0, 128.0]]
# [[171.0, 156.0], [238.0, 156.0], [238.0, 173.0], [171.0, 173.0]]
# [[387.0, 155.0], [433.0, 155.0], [433.0, 173.0], [387.0, 173.0]]
# [[172.0, 188.0], [247.0, 188.0], [247.0, 202.0], [172.0, 202.0]]
# [[377.0, 186.0], [433.0, 186.0], [433.0, 203.0], [377.0, 203.0]]
# [[172.0, 216.0], [229.0, 219.0], [228.0, 235.0], [171.0, 232.0]]
# [[388.0, 216.0], [432.0, 216.0], [432.0, 235.0], [388.0, 235.0]]
# [[172.0, 250.0], [228.0, 250.0], [228.0, 264.0], [172.0, 264.0]]
# [[394.0, 249.0], [432.0, 249.0], [432.0, 264.0], [394.0, 264.0]]
# [[173.0, 297.0], [277.0, 297.0], [277.0, 311.0], [173.0, 311.0]]
# [[380.0, 297.0], [432.0, 297.0], [432.0, 313.0], [380.0, 313.0]]
# ...

# %%
boxes = [res[0] for res in result] #
texts = [res[1][0] for res in result]
scores = [res[1][1] for res in result]
# Out:
# [0.9952478408813477,
#  0.9924618005752563,
#  0.9920256733894348,
#  0.9550370573997498,
#  0.9747217893600464,
#  0.9977073073387146,
#  0.9846222996711731,
#  0.997130811214447,
#  0.9814965128898621,
#  0.9987865090370178,
#  0.9145037531852722,
#  0.9980506896972656,
#  0.9728003144264221,
#  0.9981976747512817,
#  0.9970226287841797,
#  0.9978070259094238,
#  0.9961996078491211,
#  0.9968550801277161,
#  0.9666303992271423,
#  0.5642820000648499,
#  0.950695812702179,
#  0.9964234828948975,
#  0.9990742802619934,
#  0.8768934607505798]

# %%
# !git clone https://github.com/PaddlePaddle/PaddleOCR
# Out:
# fatal: destination path 'PaddleOCR' already exists and is not an empty directory.

# %%
font_path = os.path.join('PaddleOCR', 'doc', 'fonts', 'latin.ttf')
font_path
# Out:
# 'PaddleOCR/doc/fonts/latin.ttf'

# %%
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
plt.figure(figsize=(25,25))
annoted = draw_ocr(img, boxes, texts, scores, font_path=font_path)
plt.imshow(annoted)
